# %% [markdown]
# <a href="https://colab.research.google.com/github/No0bDarren/ADALL_github/blob/main/W2S1_Development_Tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Example: Replace this with the raw URL of your GitHub file
github_raw_url = "https://raw.githubusercontent.com/No0bDarren/ADALL_github/refs/heads/main/laptop_prices_2024_sgd_TL.csv"
try:
    df = pd.read_csv(github_raw_url)
    print("Successfully loaded data from GitHub!")
    display(df.head())
except Exception as e:
    print(f"Error loading data: {e}")
    print("Please ensure the URL is correct and the file format is compatible with `pd.read_csv`.")
# Out:
# Successfully loaded data from GitHub!
#   Brand                Model                        CPU              GPU  \
# 0  Acer             Aspire 5           Intel i9-14900HK  NVIDIA RTX 4070
# 1  Acer              Nitro 5         AMD Ryzen 9 8900HX  AMD Radeon 780M
# 2  Acer              Nitro 5          AMD Ryzen 5 8600H  NVIDIA RTX 4050
# 3  Acer        TravelMate P6  Intel Core Ultra 7 15500H  NVIDIA RTX 4060
# 4  Acer  Predator Helios 300            Intel i7-14800H  NVIDIA RTX 4070
#
#    RAM_GB Storage_Type  Storage_GB  Touchscreen  Weight_kg  Screen_Size_inch  \
# 0      64          SSD         256        False       1.56              16.0
# 1      32          SSD        1024         True       1.45              14.0
# 2      32          SSD        2048        False       1.34              14.0
# 3      16          SSD        4096         True       1.18              13.3
# 4       8          SSD        1024         True       1.31              14.0
#
# ...

# %%
#read head 5 rows
df.head()
df.shape
# Out:
# (1000, 14)

# %%
#visual histogram
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'RAM_GB'}>,
#         <Axes: title={'center': 'Storage_GB'}>,
#         <Axes: title={'center': 'Weight_kg'}>],
#        [<Axes: title={'center': 'Screen_Size_inch'}>,
#         <Axes: title={'center': 'Discount_percent'}>,
#         <Axes: title={'center': 'Price_SGD'}>],
#        [<Axes: title={'center': 'Brand_Discount'}>,
#         <Axes: title={'center': 'Member_Discount'}>, <Axes: >]],
#       dtype=object)

# %%
#plot each df graph
df.plot(kind='box', subplots=True, layout=(8,8), figsize=(15,10))
# Out:
# RAM_GB                 Axes(0.125,0.798085;0.0824468x0.0819149)
# Storage_GB          Axes(0.223936,0.798085;0.0824468x0.0819149)
# Weight_kg           Axes(0.322872,0.798085;0.0824468x0.0819149)
# Screen_Size_inch    Axes(0.421809,0.798085;0.0824468x0.0819149)
# Discount_percent    Axes(0.520745,0.798085;0.0824468x0.0819149)
# Price_SGD           Axes(0.619681,0.798085;0.0824468x0.0819149)
# Brand_Discount      Axes(0.718617,0.798085;0.0824468x0.0819149)
# Member_Discount     Axes(0.817553,0.798085;0.0824468x0.0819149)
# dtype: object

# %%
#eda of dataset
# !pip install ydata-profiling
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.df
# Out:
# ...
#          Brand                Model                        CPU  \
# 0         Acer             Aspire 5           Intel i9-14900HK
# 1         Acer              Nitro 5         AMD Ryzen 9 8900HX
# 2         Acer              Nitro 5          AMD Ryzen 5 8600H
# 3         Acer        TravelMate P6  Intel Core Ultra 7 15500H
# 4         Acer  Predator Helios 300            Intel i7-14800H
# ..         ...                  ...                        ...
# 995  Microsoft         Surface Go 3            Intel i7-14800H
# 996  Microsoft         Surface Go 3           Intel i9-14900HK
# 997  Microsoft       Surface Book 3          AMD Ryzen 5 8600H
# 998  Microsoft     Surface Laptop 5           Intel i9-14900HK
# 999  Microsoft         Surface Go 3            Intel i7-14700H
#
#                  GPU  RAM_GB Storage_Type  Storage_GB  Touchscreen  Weight_kg  \
# 0    NVIDIA RTX 4070      64          SSD         256        False       1.56
# ...

# %%
#split data for machine learning
from sklearn.model_selection import train_test_split

# %%
#set data from features and target for machine learning
X = df.drop('Price_SGD', axis=1)
y = df['Price_SGD']

# %%
#pipeline for machine learning
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
#whats next?
from sklearn.linear_model import LinearRegression
#whats next?
from sklearn.tree import DecisionTreeRegressor
#whats next?
from sklearn.ensemble import RandomForestRegressor
#what next?
from sklearn.model_selection import cross_val_score
#what next?
from sklearn.metrics import mean_squared_error
#whats next?
from sklearn.model_selection import GridSearchCV
#whats next?
from sklearn.metrics import r2_score
#whats next?
from sklearn.metrics import mean_absolute_error
#whats next?
from sklearn.metrics import mean_squared_error
#whats next?
from sklearn.metrics import mean_absolute_percentage_error
#what to do next?
from sklearn.metrics import mean_squared_log_error
#when to train model?
from sklearn.model_selection import train_test_split
